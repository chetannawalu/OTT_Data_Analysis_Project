# %% [markdown]
# ### All OTT dataset consists of TV shows and Movies as of 2021.

# %% [markdown]
# * We import all libraries for Analysis.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# * Load all OTT dataset to work on.(Netflix, Hulu, Disney, Amazon Prime)

# %%
Netflix_data = pd.read_csv(r"C:\Users\chetanN\Desktop\CSV_files\CSV files\MYSQL_data\netflix_titles.csv")
Hulu_data = pd.read_csv(r"C:\Users\chetanN\Desktop\CSV_files\CSV files\MYSQL_data\hulu_titles.csv")
Disney_data = pd.read_csv(r"C:\Users\chetanN\Desktop\CSV_files\CSV files\MYSQL_data\disney_plus_titles.csv")
Amazon_prime = pd.read_csv(r"C:\Users\chetanN\Desktop\CSV_files\CSV files\MYSQL_data\amazon_prime_titles.csv")

# %%
#Netflix_data.insert(1,'platform','Netflix')
#Hulu_data.insert(1,'platform','Hulu')
#Disney_data.insert(1,'platform','Disney')
#Amazon_prime.insert(1,'platform','Amazon prime')

# %% [markdown]
# # Netflix Data

# %%
Netflix_data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
Netflix_data['type'].value_counts()
# Out:
# Movie      6131
# TV Show    2676
# Name: type, dtype: int64

# %% [markdown]
# ### Only two type of content is available on Netflix 1: Movie,  2:TV Show
# * Movies are almost Triple than Shows.

# %% [markdown]
# * Now lets see how many indian directors are there with Movies and TV Shows.

# %%
Netflix_data[((Netflix_data['type']=='Movie') | (Netflix_data['type']=='Movie') ) & (Netflix_data['country']=='India')]
# Out:
#      show_id   type                  title                 director  \
# 24       s25  Movie                  Jeans               S. Shankar
# 105     s106  Movie       Angamaly Diaries     Lijo Jose Pellissery
# 114     s115  Movie                 Anjaam             Rahul Rawail
# 116     s117  Movie                 Dhanak          Nagesh Kukunoor
# 118     s119  Movie                Gurgaon            Shanker Raman
# ...      ...    ...                    ...                      ...
# 8772   s8773  Movie  Yamla Pagla Deewana 2           Sangeeth Sivan
# 8773   s8774  Movie    Yanda Kartavya Aahe             Kedar Shinde
# 8798   s8799  Movie               Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800  Movie                  Zenda           Avadhoot Gupte
# 8806   s8807  Movie                 Zubaan              Mozez Singh
#
#                                                    cast country  \
# 24    Prashanth, Aishwarya Rai Bachchan, Sri Lakshmi...   India
# ...

# %%
Indian_directors = Netflix_data[((Netflix_data['type']=='Movie') | (Netflix_data['type']=='Movie') ) & (Netflix_data['country']=='India')]

# %% [markdown]
# * From This dataset lets check how many Directors are from India Top 10.

# %%
c=['#DAF7A6','#FFC300','#FF5733','#C70039','#900C3F','#581845']
plt.figure(figsize=(10,7))
Indian_directors['director'].value_counts().head(10).plot(kind='barh',title='Netflix',fontsize=15,color='#9c1061')
plt.xlabel('Numbers of Movies or TV Shows',fontsize=16)
plt.ylabel('Indian Directors',fontsize=15)
plt.show()

# %%
Netflix_data[Netflix_data['type']=='TV Show']['director']
# Out:
# 1                   NaN
# 2       Julien Leclercq
# 3                   NaN
# 4                   NaN
# 5         Mike Flanagan
#              ...
# 8795                NaN
# 8796                NaN
# 8797                NaN
# 8800                NaN
# 8803                NaN
# Name: director, Length: 2676, dtype: object

# %%
Netflix_data.country.value_counts().head(10)
# Out:
# United States     2818
# India              972
# United Kingdom     419
# Japan              245
# South Korea        199
# Canada             181
# Spain              145
# France             124
# Mexico             110
# Egypt              106
# Name: country, dtype: int64

# %% [markdown]
# * On Netflix, We see India is the second largest content provider in countries.

# %%
plt.figure(figsize=(9,7))
plt.title("Netflix Category",fontsize=20)
Netflix_data['listed_in'].value_counts(ascending=True).tail(10).plot(kind='barh',fontsize=12)
plt.show()

# %% [markdown]
# ### In Above plot we see the listed_in on Netflix
# * Their are so many type of categories on Netflix.
# * Some shows are for childrens and kids.
# * Lets see the rating for the dataset.

# %%
colors = ["#355070", "#6d597a", "#b56576", "#e56b6f", "#eaac8b",'#0070ff']
plt.figure(figsize=(12,10))
plt.title('Distribution of content rating',fontsize=15)
plt.ylabel('rating',fontsize=15,labelpad=15)
Netflix_data.rating.value_counts().head(10).plot(kind='pie',autopct='%1.1f%%',colors=colors,fontsize=14,)
plt.legend()
plt.show()

# %% [markdown]
# ### As we see above about Netflix Content
# * Most of the content on Netflix is of TV-MA, TV-14, TV-PG and R.
# * This Content is only suitable for mature audience and not for childrens age < 14.
# * This type content has attract more peoples to OTT/Netflix platform, so netflix producing more content is of same type.

# %% [markdown]
# * Lets check the content on other OTT platform as well.

# %% [markdown]
# # Amazon Prime Data

# %%
Amazon_prime
# Out:
#      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# ...

# %%
plt.figure(figsize=(9,7))
plt.title(" Amazon Prime Category",fontsize=20)
Amazon_prime['listed_in'].value_counts(ascending=True).tail(10).plot(kind='barh',color='#7d0dc1',fontsize=15)
plt.show()

# %% [markdown]
# * On Amazon Prime the most common category is Drama, Comedy, Drama With Suspense, Etc.

# %%
Amazon_prime.rating.value_counts().head(10)
# Out:
# 13+      2117
# 16+      1547
# ALL      1268
# 18+      1243
# R        1010
# PG-13     393
# 7+        385
# PG        253
# NR        223
# TV-14     208
# Name: rating, dtype: int64

# %% [markdown]
# * In Rating the most content is of 13+, 16+, All, 18+ and R.
# * This is different from Netflix.

# %%
c = ["#355070", "#6d597a", "#b56576", "#e56b6f", "#eaac8b","#0070ff"]
plt.figure(figsize=(7,7))
Amazon_prime.rating.value_counts().head(10).plot(kind='pie',autopct='%1.1f%%',colors=c)
plt.show()

# %% [markdown]
# * Lets check the Directors in the Amazon dataset.

# %% [markdown]
# * Here are Top 5 Directors on Amazon Prime from All country.
# * Now check directors from India.

# %%
Amazon_prime['director'].value_counts().head(5).plot(kind='barh',color='#6d597a',fontsize=13)
plt.title('Amazon Prime : Top Directors from All country',fontsize=15)
plt.show()

# %%
Amazon_prime['type'].value_counts()
# Out:
# Movie      7814
# TV Show    1854
# Name: type, dtype: int64

# %% [markdown]
#   ##### Movies: 7814 and TV Shows: 1854
# * On Prime, we see More Movies than Tv shows compairs to Netflix.

# %%
x=Amazon_prime[Amazon_prime['country']=='India']['director'].value_counts().head().index
y=Amazon_prime[Amazon_prime['country']=='India']['director'].value_counts().head().values

# %% [markdown]
# * In Below plot, These are top 5 Directors from India.
# * We see from India for Amazon Prime, Not more than 10 Movie or TV Show are Directed by any Director.
# * Most of the content are Movies, All Top 5 Dircetors are those who produce Movies.

# %%
sns.barplot(data=Amazon_prime,x=y,y=x,orient='h')
sns.set_style('darkgrid')
sns.set({'figure.figsize':(15,7)})
plt.show()

# %% [markdown]
# # Disney data

# %%
Disney_data
# Out:
#      show_id     type                                             title  \
# 0         s1    Movie  Duck the Halls: A Mickey Mouse Christmas Special
# 1         s2    Movie                            Ernest Saves Christmas
# 2         s3    Movie                      Ice Age: A Mammoth Christmas
# 3         s4    Movie                        The Queen Family Singalong
# 4         s5  TV Show                             The Beatles: Get Back
# ...      ...      ...                                               ...
# 1445   s1446    Movie                          X-Men Origins: Wolverine
# 1446   s1447    Movie    Night at the Museum: Battle of the Smithsonian
# 1447   s1448    Movie                                   Eddie the Eagle
# 1448   s1449    Movie                              Bend It Like Beckham
# 1449   s1450    Movie             Captain Sparky vs. The Flying Saucers
#
#                                director  \
# 0     Alonso Ramirez Ramos, Dave Wasson
# ...

# %%
Disney_data['rating'].value_counts()
#Disney_data.groupby('rating').plot(kind='hist')
#sns.barplot(data=Amazon_prime,x=)
Disney_data['director'].value_counts()
# Out:
# Jack Hannah         17
# John Lasseter       16
# Paul Hoen           16
# Robert Stevenson    12
# Charles Nichols     12
#                     ..
# Simon Wells          1
# David Lynch          1
# Don Bluth            1
# Milt Schaffer        1
# Mark Waring          1
# Name: director, Length: 609, dtype: int64

# %% [markdown]
# ### Now we see Top 3 Directors From Disney and their type of content.

# %%
plt.figure(figsize=(20,10))
plt.subplot(1,3,1)
plt.ylabel('Rating',fontsize=17)
plt.title('Director: Jack Hannah',fontsize=15)
Disney_data[Disney_data['director']=='Jack Hannah']['rating'].value_counts().plot(kind='pie',fontsize=15,colors=['#09ba5e','#1e80c5','#cd150a'])
plt.subplot(1,3,2)
plt.ylabel('Rating',fontsize=17)
plt.title('Director: John Lasseter',fontsize=15)
Disney_data[Disney_data['director']=='John Lasseter']['rating'].value_counts().plot(kind='pie',fontsize=15)
plt.subplot(1,3,3)
plt.ylabel('Rating',fontsize=17)
plt.title('Director: Paul Hoen',fontsize=15)          
Disney_data[Disney_data['director']=='Paul Hoen']['rating'].value_counts().plot(kind='pie',fontsize=15,colors=['#214d6c','#1e80c5'])
plt.show()

# %%
c
# Out:
# ['#355070', '#6d597a', '#b56576', '#e56b6f', '#eaac8b', '#0070ff']

# %%
#plt.figure(figsize=(9,7))
#Disney_data['listed_in'].value_counts(ascending=True).tail(10).plot(kind='barh',color='#FF5733')
#plt.show()

# %%
a = Disney_data['listed_in'].value_counts(ascending=True).tail(10)
sns.barplot(data=Disney_data, x = a.values , y = a.index)
sns.set(rc={'figure.figsize':(20,12)},font_scale=5)

# %% [markdown]
# ### Most Rating in Disney is of TV-PG, G, PG, TV-G.
# * From Total Rating this is 76.6%

# %%
plt.figure(figsize=(10,10))
Disney_data.rating.value_counts().head(10).plot(kind='pie',autopct='%1.1f%%',fontsize=15)
plt.ylabel('Rating',fontsize=20)
plt.show()

# %% [markdown]
# # Hulu Data

# %%
Hulu_data
# Out:
#      show_id     type                           title director  cast  \
# 0         s1    Movie  Ricky Velez: Here's Everything      NaN   NaN
# 1         s2    Movie                    Silent Night      NaN   NaN
# 2         s3    Movie                    The Marksman      NaN   NaN
# 3         s4    Movie                            Gaia      NaN   NaN
# 4         s5    Movie                        Settlers      NaN   NaN
# ...      ...      ...                             ...      ...   ...
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country        date_added  release_year rating   duration  \
# ...

# %%
plt.figure(figsize=(9,7))
Hulu_data['listed_in'].value_counts(ascending=True).tail(10).plot(kind='barh',color='#ba093e',fontsize=15)
plt.show()

# %%
Hulu_data.rating.value_counts().head(10)
# Out:
# TV-14       691
# TV-MA       391
# R           345
# TV-PG       321
# PG-13       163
# TV-G        148
# PG          105
# TV-Y7        46
# 1 Season     42
# TV-Y         31
# Name: rating, dtype: int64

# %%
c = ['#197579','#FFC300','#FF5733','#C70039','#900C3F','#581845','#b70385']
plt.figure(figsize=(7,7))
Hulu_data.rating.value_counts().head(10).plot(kind='pie',colors=c,autopct='%1.1f%%',fontsize=15)
plt.ylabel('Rating',fontsize=20)
plt.show()

# %%
Release_Year = Hulu_data.release_year.value_counts().sort_index(ascending=False).head(10)
Release_Year
# Out:
# 2021    226
# 2020    377
# 2019    412
# 2018    270
# 2017    229
# 2016    165
# 2015    163
# 2014    129
# 2013    126
# 2012    119
# Name: release_year, dtype: int64

# %%
plt.figure(figsize=(9,7))
Release_Year.plot(kind='barh',fontsize=15)
plt.title('Movie/TV Shows Release per Year',fontsize=17)
plt.ylabel('Year',fontsize=17)
plt.xlabel('Total movies/shows',fontsize=17)
plt.show()
#sns.barplot(data=Hulu_data, x = Release_Year.index, y = Release_Year.values)

# %% [markdown]
# * In 2019 Content is Higher compairs to other years and it is decreases in next two years(2020,2021).
# * This is maybe because of covid-19 impact on the industry.

# %%
index=['Action, Adventure, Anime'              
,'Action, Adventure, Drama'                
,'Action, Thriller'                        
,'Anime'                                   
,'Comedy'                                  
,'Comedy, Drama'                           
,'Comedy, Romance'                         
,'Cooking & Food, Lifestyle & Culture'     
,'Crime, Documentaries'                    
,'Documentaries'                          
,'Documentaries, Science & Technology'     
,'Documentaries, Sports'                   
,'Drama'                                   
,'Horror'                                  
,'Horror, Thriller'                        
,'Kids'                                    
,'News'                                    
,'Reality'                                 
,'Sports'                                  
,'Thriller']

# %%
Hulu_data.sort_values('release_year',ascending=False)
colors = ["#355070", "#6d597a", "#b56576", "#e56b6f", "#eaac8b",'#0070ff']
plt.figure(figsize=(25,17))
plt.subplot(1,2,1)
plt.title('Year 2016 - 2018')
Hulu_data[(Hulu_data['release_year']<2019) & (Hulu_data['release_year']>=2016)]['listed_in'].value_counts().head(10).sort_values().plot(kind='barh',color='green',fontsize=19)
plt.subplot(1,2,2)
plt.title('Year 2019 - 2021')
Hulu_data[Hulu_data['release_year']>=2019]['listed_in'].value_counts().head(10).sort_values().plot(kind='barh',color='red',fontsize=19)
plt.show()

# %% [markdown]
# * Top 10 listed_in data Before 2019 and After 2019.
# * Here also we see Before 2019 and After 2019 effect of covid.

# %%
plt.figure(figsize=(15,8))
Hulu_data[Hulu_data['release_year']>=2019]['listed_in'].value_counts().head(20)
# Out:
# Documentaries                          133
# News                                    44
# Horror, Thriller                        40
# Sports                                  32
# Comedy                                  31
# Drama                                   24
# Reality                                 23
# Horror                                  23
# Documentaries, Sports                   22
# Documentaries, Science & Technology     21
# Action, Adventure, Anime                19
# Anime                                   19
# Comedy, Romance                         17
# Action, Thriller                        16
# Kids                                    16
# Action, Adventure, Drama                13
# Comedy, Drama                           13
# Crime, Documentaries                    13
# Thriller                                11
# Cooking & Food, Lifestyle & Culture     11
# Name: listed_in, dtype: int64

# %%
Hulu_data[Hulu_data['release_year']>=2019]['listed_in'].value_counts().head(20).sort_index()
# Out:
# Action, Adventure, Anime                19
# Action, Adventure, Drama                13
# Action, Thriller                        16
# Anime                                   19
# Comedy                                  31
# Comedy, Drama                           13
# Comedy, Romance                         17
# Cooking & Food, Lifestyle & Culture     11
# Crime, Documentaries                    13
# Documentaries                          133
# Documentaries, Science & Technology     21
# Documentaries, Sports                   22
# Drama                                   24
# Horror                                  23
# Horror, Thriller                        40
# Kids                                    16
# News                                    44
# Reality                                 23
# Sports                                  32
# Thriller                                11
# Name: listed_in, dtype: int64

# %%
Hulu_data.shape
# Out:
# (3073, 12)

# %%
#index=['Action, Adventure, Anime','Action, Adventure, Drama','Action, Thriller','Anime','Comedy']
Hulu_data[(Hulu_data['release_year']<2019) & (Hulu_data['release_year']>=2016)]
# Out:
#      show_id     type                          title director  cast  \
# 22       s23  TV Show          Little Women: Atlanta      NaN   NaN
# 25       s26  TV Show              Seven Year Switch      NaN   NaN
# 26       s27    Movie                    Sleepwalker      NaN   NaN
# 30       s31  TV Show                 Catfish México      NaN   NaN
# 33       s34  TV Show          La Culpa es de Cortés      NaN   NaN
# ...      ...      ...                            ...      ...   ...
# 2825   s2826  TV Show   Undefeated Bahamut Chronicle      NaN   NaN
# 2826   s2827  TV Show                    Dimension W      NaN   NaN
# 2827   s2828  TV Show   Grimgar, Ashes and Illusions      NaN   NaN
# 2832   s2833  TV Show                    Divine Gate      NaN   NaN
# 2836   s2837  TV Show  Prince of Stride: Alternative      NaN   NaN
#
#             country        date_added  release_year rating   duration  \
# 22    United States  October 15, 2021          2016  TV-14  2 Seasons
# ...
